# %% [markdown]
# <a href="https://colab.research.google.com/github/LarsAmker/ExplainGAN/blob/master/Pneumonia_compact.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import and access the data

# %%
# Colab library to upload files to notebook
from google.colab import files

# Install Kaggle library
# !pip install -q kaggle

# %%
#!pwd
# !mkdir ~/.kaggle
#!cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %% [markdown]
# The kaggle.json file is needed to get the data directly from kaggle. Copy it over from my google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# copy the json file from google drive into the kaggle directory
# !cp "/content/gdrive/My Drive/kaggle.json" ~/.kaggle

# %%
# Download pneumonia data (first line makes kaggle API key unreadable)
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# the zip file is listed in the left hand pane after the download. We need to unzip and create paths
# Out:
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:30<00:00, 13.5MB/s]
# 100% 2.29G/2.29G [00:30<00:00, 80.5MB/s]

# %%
# !unzip chest-xray-pneumonia.zip

# %%
import os
import glob
import h5py
import shutil
import imgaug as aug
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import imgaug.augmenters as iaa
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D
from keras.layers import GlobalMaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
import cv2
from keras import backend as K
color = sns.color_palette()
# %matplotlib inline

# added tensorflow and stuff from the MNIST classifier:
import tensorflow as tf
from __future__ import absolute_import, division, print_function, unicode_literals
import PIL
import time
from IPython import display
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %%
# My directory is called "content" instead of "input" as in the original code
#os.listdir("../content/chest_xray/chest_xray")

# %% [markdown]
# NAIN had a code box fixing some random seeds here. Not compatible with tf2 however, therefore deleted and saved in testPneumonia/reproducability

# %%
# Clone the github repo to get access to the outsourced building blocks
# !git clone https://github.com/LarsAmker/ExplainGAN
# Out:
# Cloning into 'ExplainGAN'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 489 (delta 55), reused 0 (delta 0), pack-reused 378
# Receiving objects: 100% (489/489), 2.08 MiB | 4.62 MiB/s, done.
# Resolving deltas: 100% (273/273), done.

# %% [markdown]
# ## Make the data accessible

# %% [markdown]
# The dataset is divided into three sets: 1) train set 2) validation set and 3) test set. Let's grab the dataset

# %% [markdown]
# Each of the above directories contains two sub-directories:
#
# NORMAL: These are the samples that describe the normal (no pneumonia) case.
#
# PNEUMONIA: This directory contains those samples that are the pneumonia cases.

# %%
# %run ExplainGAN/blocksPneumonia/data

# %% [markdown]
# In NAIN's classifier, the training data is handled differently: He just created a dataframe of paths to the images and the labels in a second column. Then he used a data generator for the training. Using the generator in the training of my multi-network ExplainGAN model did not work (or at least I did not figure out how to make it work), so I transfered the data import steps of validation and test data and I do the batching in the way of my MNIST code later on, before the training.

# %% [markdown]
# # Classifier (NAIN's depthwise kernel)
#
# Build and compile an empty model and then load the weights for it from my google drive. These weights were created and saved in the notebook "PneumoniaClassifier.ipynb"

# %%
# changed the format of this method due to compatibility with tensorflow 2
# The original version from NAIN worked with "x=...(x)" steps, my theory is that this x is the placeholder that lead to errors
from tensorflow.keras import layers

def build_model():
  model = tf.keras.Sequential()
  model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv1_1', input_shape=[224, 224, 3]))
  model.add(layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv1_2', input_shape=[224, 224, 3]))
  model.add(layers.MaxPooling2D((2,2), name='pool'))

  model.add(layers.SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_1'))
  model.add(layers.SeparableConv2D(128, (3,3), activation='relu', padding='same', name='Conv2_2'))
  model.add(layers.MaxPooling2D((2,2), name='pool2'))

  model.add(layers.SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_1'))
  model.add(layers.BatchNormalization(name='bn1'))
  model.add(layers.SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_2'))
  model.add(layers.BatchNormalization(name='bn2'))
  model.add(layers.SeparableConv2D(256, (3,3), activation='relu', padding='same', name='Conv3_3'))
  model.add(layers.MaxPooling2D((2,2), name='pool3'))

  model.add(layers.SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_1'))
  model.add(layers.BatchNormalization(name='bn3'))
  model.add(layers.SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_2'))
  model.add(layers.BatchNormalization(name='bn4'))
  model.add(layers.SeparableConv2D(512, (3,3), activation='relu', padding='same', name='Conv4_3'))
  model.add(layers.MaxPooling2D((2,2), name='pool4'))

  model.add(layers.Flatten(name='flatten'))
  model.add(layers.Dense(1024, activation='relu', name='fc1'))
  model.add(layers.Dropout(0.7, name='dropout1'))
  model.add(layers.Dense(512, activation='relu', name='fc2'))
  model.add(layers.Dropout(0.5, name='dropout2'))
  model.add(layers.Dense(2, activation='softmax', name='fc3'))
  
  return model

# %%
classifier =  build_model()
#model.summary()

# %%
# opt = RMSprop(lr=0.0001, decay=1e-6)
opt = tf.keras.optimizers.Adam(lr=0.0001, decay=1e-5)
es = EarlyStopping(patience=5)
chkpt = ModelCheckpoint(filepath='best_model_todate', save_best_only=True, save_weights_only=True)
classifier.compile(loss='binary_crossentropy', metrics=['accuracy'],optimizer=opt)

# %%
classifier.load_weights('/content/gdrive/My Drive/Colab Notebooks/DepthwiseWeights')

# %% [markdown]
# ### Testing classifier

# %%
# Evaluation on test dataset
test_loss, test_score = classifier.evaluate(test_data, test_labels, batch_size=16)
print("Loss on test set: ", test_loss)
print("Accuracy on test set: ", test_score)
# Out:
# 39/39 [==============================] - 1s 34ms/step - loss: 1.4144 - accuracy: 0.7965
# Loss on test set:  1.4144046306610107
# Accuracy on test set:  0.7964743375778198

# %%
# Get predictions
preds = classifier.predict(test_data, batch_size=16)
preds = np.argmax(preds, axis=-1)

# Original labels
orig_test_labels = np.argmax(test_labels, axis=-1)

#print(orig_test_labels.shape)
#print(preds.shape)

# %%
# Get the confusion matrix
cm = confusion_matrix(orig_test_labels, preds)
plt.figure()
#plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, alpha=0.7,cmap=plt.cm.Blues)
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
plt.yticks(range(2), ['Normal', 'Pneumonia'], fontsize=16)
#plt.show()

# %%
# Calculate Precision and Recall
tn, fp, fn, tp = cm.ravel()

precision = tp/(tp+fp)
recall = tp/(tp+fn)
#print("Recall of the classifier is {:.2f}".format(recall))
#print("Precision of the classifier is {:.2f}".format(precision))

# %% [markdown]
# Running everything up to this point takes 3 and a half minutes.

# %% [markdown]
# # ExplainGAN

# %%
print(train_data.shape) # this is a data frame of paths to the images and their labels.
# The train data generator gets the images from the paths. This saves memory compared to saving all training images
print(valid_data.shape)
print(test_data.shape)
# Out:
# (5216, 224, 224, 3)
# (16, 224, 224, 3)
# (624, 224, 224, 3)

# %% [markdown]
# ## Encoder

# %%
# Copied from https://blog.keras.io/building-autoencoders-in-keras.html, added flattening at the end
# Also changed the activation function from relu to sigmoid to not get exploding latent variables
# Maybe change this back if I train the encoder separately before training the rest of ExplainGAN. Then, also move the flattening

# Change input shape, but use only one of the three RGB channels
def make_encoder_model(activ_fct):
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(16, (3, 3), activation=activ_fct, padding='same', use_bias=True,
                                     input_shape=[224, 224, 3]))
    model.add(layers.MaxPooling2D((2,2), padding='same'))

    model.add(layers.Conv2D(8, (3, 3), activation=activ_fct, padding='same', use_bias=True))
    model.add(layers.MaxPooling2D((2,2), padding='same'))

    model.add(layers.Conv2D(8, (3, 3), activation=activ_fct, padding='same', use_bias=True))
    model.add(layers.MaxPooling2D((2,2), padding='same'))
    model.add(layers.Conv2D(8, (3, 3), activation=activ_fct, padding='same', use_bias=True))
    model.add(layers.MaxPooling2D((2,2), padding='same'))
    model.add(layers.Flatten())
    
    return model
# At this point the representation is (4, 4, 8) i.e. 128-dimensional
# The convolutions here don't decrease the 2D dimension because they have default (1,1) strides. The MaxPooling does

# %%
encoder0 = make_encoder_model(activ_fct='relu')
encoder1 = make_encoder_model(activ_fct='relu')
#encoder0.summary()

# %%
encoded = encoder0(test_data[0:1,:,:,:])

# %% [markdown]
# ## Generators
#
# The generator_start is the biggest part of ExplainGAN, i.e. the one with the most weights. I already ran into one OOM error with this version of the code after building ~5 models with 123 millions of weights. The vast majority of weights appears in the very first, dense, layer.
#
# Make this smaller somehow. Let's try to create fewer 7*7 images (in MNIST, we created 128 of these from an encoded vector of length 128). Try 128 for now. Then we have only 10 millions of weights in generator_start

# %%
# This generator is based on the DCGAN generator. But now, we need 3 outputs and not just one!
# Therefore tear it apart in the middle. We will use the second part three times to get recon and trafo and mask 
def make_generator_model_start():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*128, use_bias=False, input_shape=(1568,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())
    # Create images of size 7*7 with 128 channels, all connected to the 128 nodes of the encoded original image
    # In the next 2 lines, the tensor is actually reshaped into that channel form

    model.add(layers.Reshape((7, 7, 128)))
    assert model.output_shape == (None, 7, 7, 128) # Note: None is the batch size

    # now move 5*5*128(channels) filters over the 7*7*128(channels) images in 1,1 strides. Do this for each of the 64 output channels.
    # 64 is the number of different filters we apply. Because of the big number of input channels, each filter is already huge
    # The number of parameters here is 5*5*128 (filter weights) *64 (number of filters)
    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    return model
    
 
# Now the second part. Apply this three times to get reconstruction and transformation and mask
# Because of the splitting, I also needed to add the input shape in the first layer of this second part.
def make_generator_model_end_sigmoid(): # second version to get a mask with values in [0,1] instead of [-1,1] with tanh
    # By taking strides of 2, the size of the image gets doubled in length and width.
    # This is the case, because we do a backwards convolution. If we get a 7*7 image by taking (2,2)-strides, we must have started with 14*14
    model = tf.keras.Sequential()
    model.add(layers.Conv2DTranspose(32, (5, 5), strides=(2, 2), padding='same', use_bias=False, input_shape=(7,7,64)))
    assert model.output_shape == (None, 14, 14, 32)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(16, (5, 5), strides=(2, 2), padding='same', use_bias=False, input_shape=(14,14,32)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(8, (5, 5), strides=(2, 2), padding='same', use_bias=False, input_shape=(28,28,16)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(8, (5, 5), strides=(2, 2), padding='same', use_bias=False, input_shape=(56,56,8)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='sigmoid'))
    assert model.output_shape == (None, 224, 224, 1)
    return model

# %%
generator_start = make_generator_model_start()
#generator_start.summary()
reconstructor = make_generator_model_end_sigmoid()
#reconstructor.summary()

# %%
gen_started = generator_start(encoded)
#gen_started # shape (1,7,7,64)

# %%
reconstructed = reconstructor(gen_started)
#reconstructed # shape (1,224,224,1) like a grayscale x-ray scan

# %% [markdown]
# ## Loss function and optimizers

# %%
# inputs of loss_recon are two images, the original one and its reconstruction 
def loss_recon(x, reconstruction):
  difference = tf.subtract(x,reconstruction)
  # reshape 224*224 to one vector in order to apply the l2 norm to it
  # The -1 in the first dimension make sure that the number of images stays the same, images shall not be combined
  difference = tf.reshape(difference, [-1,50176,1])
  return tf.math.square(tf.norm(difference, ord=2, axis=1))

# %%
# Testing
#loss_recon(valid_data[:,:,:,0], valid_data[:,:,:,0])

# %%
enc0_optimizer = tf.keras.optimizers.Adam(1e-4)
enc1_optimizer = tf.keras.optimizers.Adam(1e-4)
gen_start_optimizer = tf.keras.optimizers.Adam(1e-4)
recon_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ## Experimenation

# %%
images = valid_data
predicted_classes = classifier.predict(images) # model takes (224,224,3) as input
predicted_classes = np.argmax(predicted_classes, axis=1) # now we have the actual predictions
predicted_classes = tf.reshape(predicted_classes, [-1,1]) # make it compatible with tensors below
predicted_classes = tf.cast(predicted_classes, tf.float32) # change type to float for multiplications
predicted_classes

images_grayscale = images[:,:,:,0:1]
#images_grayscale.shape

# %%
with tf.GradientTape() as enc0_tape, tf.GradientTape() as enc1_tape, tf.GradientTape() as gen_start_tape, tf.GradientTape() as recon_tape:
  z_as0 = encoder0(images)
  z_as1 = encoder1(images)
  gen_from_pred0 = generator_start(z_as0)
  gen_from_pred1 = generator_start(z_as1)
  recon_from_pred0 = reconstructor(gen_from_pred0)
  recon_from_pred1 = reconstructor(gen_from_pred1)
  print("recon0 shape:", recon_from_pred0.shape)
  print("recon1 shape:", recon_from_pred1.shape)
  print("images_grayscale shape:", images_grayscale.shape)

  loss_recon0 = loss_recon(images_grayscale, recon_from_pred0)
  loss_recon1 = loss_recon(images_grayscale, recon_from_pred1)
  print("loss_recon0 shape:", loss_recon0.shape)
  loss_r0 = tf.math.multiply(1-predicted_classes, loss_recon0) # set the loss for the wrong recons to 0
  loss_r1 = tf.math.multiply(predicted_classes, loss_recon1) # set the loss for the wrong recons to 0
  loss_r = (loss_r0 + loss_r1)*0.0005
  loss_summed = loss_r
  print("loss_summed shape:", loss_summed.shape)

  gradients_of_enc0 = enc0_tape.gradient(loss_summed, encoder0.trainable_variables)
  gradients_of_enc1 = enc1_tape.gradient(loss_summed, encoder1.trainable_variables)
  gradients_of_gen_start = gen_start_tape.gradient(loss_summed, generator_start.trainable_variables)
  gradients_of_recon = recon_tape.gradient(loss_summed, reconstructor.trainable_variables)

  enc0_optimizer.apply_gradients(zip(gradients_of_enc0, encoder0.trainable_variables))
  enc1_optimizer.apply_gradients(zip(gradients_of_enc1, encoder1.trainable_variables))
  gen_start_optimizer.apply_gradients(zip(gradients_of_gen_start, generator_start.trainable_variables))
  recon_optimizer.apply_gradients(zip(gradients_of_recon, reconstructor.trainable_variables))

  print('loss_r: ', tf.reduce_max(loss_r), tf.reduce_min(loss_r), tf.reduce_mean(loss_r))
# Out:
# recon0 shape: (16, 224, 224, 1)
# recon1 shape: (16, 224, 224, 1)
# images_grayscale shape: (16, 224, 224, 1)
# loss_recon0 shape: (16, 1)
# loss_summed shape: (16, 1)
# loss_r:  tf.Tensor(2.433419, shape=(), dtype=float32) tf.Tensor(1.208833, shape=(), dtype=float32) tf.Tensor(1.6498693, shape=(), dtype=float32)

# %%
# Changes compared to the DCGAN version: test_input is the first real image(s) instead of a random seed
def generate_and_save_images(epoch, test_input, index):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  original = test_input[index:index+1,:,:,:]
  prediction = classifier.predict(original)
  prediction = np.argmax(prediction, axis=1)
  if prediction == 0:
    z = encoder0(original, training=False)
  if prediction == 1:
    z = encoder1(original, training=False)
  gen_from_pred = generator_start(z, training=False)
  recon_from_pred = reconstructor(gen_from_pred, training=False)
  #trafo_from_pred = transformator(gen_from_pred, training=False)
  #mask_from_pred = mask(gen_from_pred, training=False)
  #comp_from_pred = create_composite(original, trafo_from_pred, mask_from_pred)
  
  fig = plt.figure(figsize=(10,10))
  plt.subplot(1, 2, 1)
  plt.imshow(original[0, :, :, 0] * 127.5 + 127.5, cmap='gray')
  plt.axis('off')
  plt.subplot(1, 2, 2)
  plt.imshow(recon_from_pred[0, :, :, 0] * 127.5 + 127.5, cmap='gray')
  plt.axis('off')
  #plt.subplot(1, 5, 3)
  #plt.imshow(trafo_from_pred[0, :, :, 0] * 127.5 + 127.5, cmap='gray')
  #plt.axis('off')
  #plt.subplot(1, 5, 4)
  #plt.imshow(mask_from_pred[0, :, :, 0] * 127.5 + 127.5, cmap='gray')
  #plt.axis('off')
  #plt.subplot(1, 5, 5)
  #plt.imshow(comp_from_pred[0, :, :, 0] * 127.5 + 127.5, cmap='gray')
  #plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
set = test_data
#generate_and_save_images(1,set,index=20)
#generate_and_save_images(1,set,index=21)
#generate_and_save_images(1,set,index=22)

# %% [markdown]
# ##Training

# %%
def train_step(images):
  predicted_classes = classifier.predict(images) # model takes (224,224,3) as input
  predicted_classes = np.argmax(predicted_classes, axis=1) # now we have the actual predictions
  predicted_classes = tf.reshape(predicted_classes, [-1,1]) # make it compatible with tensors below
  predicted_classes = tf.cast(predicted_classes, tf.float32) # change type to float for multiplications
  
  images_grayscale = images[:,:,:,0:1] #needed for loss_computations

  with tf.GradientTape() as enc0_tape, tf.GradientTape() as enc1_tape, tf.GradientTape() as gen_start_tape, tf.GradientTape() as recon_tape:
    z_as0 = encoder0(images)
    z_as1 = encoder1(images)
    gen_from_pred0 = generator_start(z_as0)
    gen_from_pred1 = generator_start(z_as1)
    recon_from_pred0 = reconstructor(gen_from_pred0)
    recon_from_pred1 = reconstructor(gen_from_pred1)
    #print("recon0 shape:", recon_from_pred0.shape)
    #print("recon1 shape:", recon_from_pred1.shape)
    #print("images_grayscale shape:", images_grayscale.shape)

    loss_recon0 = loss_recon(images_grayscale, recon_from_pred0)
    loss_recon1 = loss_recon(images_grayscale, recon_from_pred1)
    #print("loss_recon0 shape:", loss_recon0.shape)
    loss_r0 = tf.math.multiply(1-predicted_classes, loss_recon0) # set the loss for the wrong recons to 0
    loss_r1 = tf.math.multiply(predicted_classes, loss_recon1) # set the loss for the wrong recons to 0
    loss_r = (loss_r0 + loss_r1)*0.0005
    loss_summed = loss_r
    #print("loss_summed shape:", loss_summed.shape)

    gradients_of_enc0 = enc0_tape.gradient(loss_summed, encoder0.trainable_variables)
    gradients_of_enc1 = enc1_tape.gradient(loss_summed, encoder1.trainable_variables)
    gradients_of_gen_start = gen_start_tape.gradient(loss_summed, generator_start.trainable_variables)
    gradients_of_recon = recon_tape.gradient(loss_summed, reconstructor.trainable_variables)

    enc0_optimizer.apply_gradients(zip(gradients_of_enc0, encoder0.trainable_variables))
    enc1_optimizer.apply_gradients(zip(gradients_of_enc1, encoder1.trainable_variables))
    gen_start_optimizer.apply_gradients(zip(gradients_of_gen_start, generator_start.trainable_variables))
    recon_optimizer.apply_gradients(zip(gradients_of_recon, reconstructor.trainable_variables))

    print('loss_r: ', tf.reduce_max(loss_r), tf.reduce_min(loss_r), tf.reduce_mean(loss_r))

# %%
# Checking, seems to work just fine. Loss changes from step to step
#train_step(test_data) # produces OOM error
#train_step(valid_data) # still works
train_step(train_data[0:16,:,:,:]) # works
# Out:
# loss_r:  tf.Tensor(1.8329737, shape=(), dtype=float32) tf.Tensor(1.0064462, shape=(), dtype=float32) tf.Tensor(1.4584286, shape=(), dtype=float32)

# %%
# Batch and shuffle the training (and test - just for experiments) data
# We can play around with the batch size a bit
BATCH_SIZE = 16
train_dataset = tf.data.Dataset.from_tensor_slices(train_data).shuffle(len(train_labels)).batch(BATCH_SIZE)
test_dataset = tf.data.Dataset.from_tensor_slices(test_data).shuffle(len(test_labels)).batch(BATCH_SIZE)
EPOCHS = 1
# batches have the correct shape for the train_step

# %%
def train(dataset, epochs):
  for epoch in range(epochs):
    start = time.time()

    for image_batch in dataset:
      # Here we use the batching of the dataset
      # call the function train_step (defined in the longest code box)
      train_step(image_batch)

    # Produce images for the GIF as we go (from DCGAN)
    #display.clear_output(wait=True)
    generate_and_save_images(epoch + 1, train_data, index=0) # still input train_images here. Would be nice to use dataset instead!!
    
    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  #display.clear_output(wait=True)

# %%
train(train_dataset, EPOCHS)
# Out:
# loss_r:  tf.Tensor(2.076174, shape=(), dtype=float32) tf.Tensor(0.75629485, shape=(), dtype=float32) tf.Tensor(1.5376146, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.014659, shape=(), dtype=float32) tf.Tensor(0.8910942, shape=(), dtype=float32) tf.Tensor(1.3470349, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1042018, shape=(), dtype=float32) tf.Tensor(0.94936943, shape=(), dtype=float32) tf.Tensor(1.2537588, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.9050202, shape=(), dtype=float32) tf.Tensor(0.69232714, shape=(), dtype=float32) tf.Tensor(1.6526047, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.2852695, shape=(), dtype=float32) tf.Tensor(0.6369406, shape=(), dtype=float32) tf.Tensor(1.4130924, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9489741, shape=(), dtype=float32) tf.Tensor(0.65095955, shape=(), dtype=float32) tf.Tensor(1.5242914, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3964791, shape=(), dtype=float32) tf.Tensor(1.0419405, shape=(), dtype=float32) tf.Tensor(1.6415235, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.268336, shape=(), dtype=float32) tf.Tensor(0.7838421, shape=(), dtype=float32) tf.Tensor(1.3770151, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.019908, shape=(), dtype=float32) tf.Tensor(0.51623154, shape=(), dtype=float32) tf.Tensor(1.2271893, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7422444, shape=(), dtype=float32) tf.Tensor(0.9259743, shape=(), dtype=float32) tf.Tensor(1.3586205, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.4933534, shape=(), dtype=float32) tf.Tensor(0.7097452, shape=(), dtype=float32) tf.Tensor(1.343859, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3392813, shape=(), dtype=float32) tf.Tensor(0.6714543, shape=(), dtype=float32) tf.Tensor(1.527837, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0272136, shape=(), dtype=float32) tf.Tensor(0.51586217, shape=(), dtype=float32) tf.Tensor(1.239244, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.196542, shape=(), dtype=float32) tf.Tensor(0.986981, shape=(), dtype=float32) tf.Tensor(1.3460624, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1053913, shape=(), dtype=float32) tf.Tensor(0.73757017, shape=(), dtype=float32) tf.Tensor(1.4687637, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3594303, shape=(), dtype=float32) tf.Tensor(0.92841095, shape=(), dtype=float32) tf.Tensor(1.487631, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9585947, shape=(), dtype=float32) tf.Tensor(0.98831475, shape=(), dtype=float32) tf.Tensor(1.4557108, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.117521, shape=(), dtype=float32) tf.Tensor(0.98104817, shape=(), dtype=float32) tf.Tensor(1.4247262, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.5029433, shape=(), dtype=float32) tf.Tensor(0.5821375, shape=(), dtype=float32) tf.Tensor(1.5990673, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3014956, shape=(), dtype=float32) tf.Tensor(0.8714834, shape=(), dtype=float32) tf.Tensor(1.4522746, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7852193, shape=(), dtype=float32) tf.Tensor(0.9019712, shape=(), dtype=float32) tf.Tensor(1.4169939, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0591252, shape=(), dtype=float32) tf.Tensor(0.76385707, shape=(), dtype=float32) tf.Tensor(1.3189125, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.327218, shape=(), dtype=float32) tf.Tensor(0.83495367, shape=(), dtype=float32) tf.Tensor(1.5823013, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7395313, shape=(), dtype=float32) tf.Tensor(0.72226, shape=(), dtype=float32) tf.Tensor(1.2763821, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3396914, shape=(), dtype=float32) tf.Tensor(0.683805, shape=(), dtype=float32) tf.Tensor(1.46912, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.2664073, shape=(), dtype=float32) tf.Tensor(1.1862937, shape=(), dtype=float32) tf.Tensor(1.510931, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.803343, shape=(), dtype=float32) tf.Tensor(0.7695512, shape=(), dtype=float32) tf.Tensor(1.4046711, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7705218, shape=(), dtype=float32) tf.Tensor(1.0149821, shape=(), dtype=float32) tf.Tensor(1.4256344, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0207398, shape=(), dtype=float32) tf.Tensor(0.6438528, shape=(), dtype=float32) tf.Tensor(1.3052088, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.5040066, shape=(), dtype=float32) tf.Tensor(0.98910034, shape=(), dtype=float32) tf.Tensor(1.6256299, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1384032, shape=(), dtype=float32) tf.Tensor(0.76209956, shape=(), dtype=float32) tf.Tensor(1.3863213, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.9422133, shape=(), dtype=float32) tf.Tensor(1.0513504, shape=(), dtype=float32) tf.Tensor(1.4795457, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0839214, shape=(), dtype=float32) tf.Tensor(0.91635144, shape=(), dtype=float32) tf.Tensor(1.4478427, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7304068, shape=(), dtype=float32) tf.Tensor(0.747678, shape=(), dtype=float32) tf.Tensor(1.3772678, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7988735, shape=(), dtype=float32) tf.Tensor(0.9587512, shape=(), dtype=float32) tf.Tensor(1.313406, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0879192, shape=(), dtype=float32) tf.Tensor(0.8916433, shape=(), dtype=float32) tf.Tensor(1.4200289, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3278408, shape=(), dtype=float32) tf.Tensor(0.47449732, shape=(), dtype=float32) tf.Tensor(1.3135927, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.850517, shape=(), dtype=float32) tf.Tensor(0.6431328, shape=(), dtype=float32) tf.Tensor(1.2624516, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.3766503, shape=(), dtype=float32) tf.Tensor(0.5191379, shape=(), dtype=float32) tf.Tensor(1.3995748, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.938822, shape=(), dtype=float32) tf.Tensor(0.80234855, shape=(), dtype=float32) tf.Tensor(1.2916746, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.111782, shape=(), dtype=float32) tf.Tensor(0.94381493, shape=(), dtype=float32) tf.Tensor(1.4033544, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.2247298, shape=(), dtype=float32) tf.Tensor(0.6658079, shape=(), dtype=float32) tf.Tensor(1.3853267, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.5574644, shape=(), dtype=float32) tf.Tensor(0.71572876, shape=(), dtype=float32) tf.Tensor(1.445989, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.268931, shape=(), dtype=float32) tf.Tensor(0.83069277, shape=(), dtype=float32) tf.Tensor(1.3858812, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9546504, shape=(), dtype=float32) tf.Tensor(0.79242843, shape=(), dtype=float32) tf.Tensor(1.4124638, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5723122, shape=(), dtype=float32) tf.Tensor(0.6333522, shape=(), dtype=float32) tf.Tensor(1.176889, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7907113, shape=(), dtype=float32) tf.Tensor(0.7125946, shape=(), dtype=float32) tf.Tensor(1.2639909, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.8480126, shape=(), dtype=float32) tf.Tensor(0.45502043, shape=(), dtype=float32) tf.Tensor(1.1934003, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5500245, shape=(), dtype=float32) tf.Tensor(0.7053557, shape=(), dtype=float32) tf.Tensor(1.1111223, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5345803, shape=(), dtype=float32) tf.Tensor(0.6922314, shape=(), dtype=float32) tf.Tensor(1.1664913, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9904338, shape=(), dtype=float32) tf.Tensor(0.50406486, shape=(), dtype=float32) tf.Tensor(1.2014115, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5946515, shape=(), dtype=float32) tf.Tensor(0.3344556, shape=(), dtype=float32) tf.Tensor(1.1170449, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.179976, shape=(), dtype=float32) tf.Tensor(0.47210503, shape=(), dtype=float32) tf.Tensor(1.132827, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6237029, shape=(), dtype=float32) tf.Tensor(0.6842988, shape=(), dtype=float32) tf.Tensor(1.1482437, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.8363638, shape=(), dtype=float32) tf.Tensor(0.6863104, shape=(), dtype=float32) tf.Tensor(1.1065512, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9624017, shape=(), dtype=float32) tf.Tensor(0.87994903, shape=(), dtype=float32) tf.Tensor(1.3411005, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5965652, shape=(), dtype=float32) tf.Tensor(0.65586495, shape=(), dtype=float32) tf.Tensor(1.1522532, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5639888, shape=(), dtype=float32) tf.Tensor(0.77586603, shape=(), dtype=float32) tf.Tensor(1.2252288, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9907119, shape=(), dtype=float32) tf.Tensor(0.6356275, shape=(), dtype=float32) tf.Tensor(1.1115012, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.68196, shape=(), dtype=float32) tf.Tensor(0.3789067, shape=(), dtype=float32) tf.Tensor(1.038388, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7114415, shape=(), dtype=float32) tf.Tensor(0.8048367, shape=(), dtype=float32) tf.Tensor(1.2108123, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6492077, shape=(), dtype=float32) tf.Tensor(0.6559226, shape=(), dtype=float32) tf.Tensor(1.0749917, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.2734597, shape=(), dtype=float32) tf.Tensor(0.6117937, shape=(), dtype=float32) tf.Tensor(1.1258482, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.733486, shape=(), dtype=float32) tf.Tensor(0.41286227, shape=(), dtype=float32) tf.Tensor(1.127297, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6805341, shape=(), dtype=float32) tf.Tensor(0.7324554, shape=(), dtype=float32) tf.Tensor(1.1787734, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6701376, shape=(), dtype=float32) tf.Tensor(0.6590958, shape=(), dtype=float32) tf.Tensor(1.0622876, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9283088, shape=(), dtype=float32) tf.Tensor(0.6343604, shape=(), dtype=float32) tf.Tensor(1.1066097, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4320699, shape=(), dtype=float32) tf.Tensor(0.47320876, shape=(), dtype=float32) tf.Tensor(0.9644909, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.8105946, shape=(), dtype=float32) tf.Tensor(0.625626, shape=(), dtype=float32) tf.Tensor(1.1142555, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1669388, shape=(), dtype=float32) tf.Tensor(0.5840752, shape=(), dtype=float32) tf.Tensor(1.0842636, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.607031, shape=(), dtype=float32) tf.Tensor(0.52543455, shape=(), dtype=float32) tf.Tensor(0.9902917, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2466516, shape=(), dtype=float32) tf.Tensor(0.6252262, shape=(), dtype=float32) tf.Tensor(0.9097419, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6032708, shape=(), dtype=float32) tf.Tensor(0.60225993, shape=(), dtype=float32) tf.Tensor(1.083889, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3786684, shape=(), dtype=float32) tf.Tensor(0.54358864, shape=(), dtype=float32) tf.Tensor(0.95095074, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4527982, shape=(), dtype=float32) tf.Tensor(0.6703074, shape=(), dtype=float32) tf.Tensor(0.99193126, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2365112, shape=(), dtype=float32) tf.Tensor(0.6035239, shape=(), dtype=float32) tf.Tensor(0.87936026, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6559254, shape=(), dtype=float32) tf.Tensor(0.41866922, shape=(), dtype=float32) tf.Tensor(0.97952473, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.871698, shape=(), dtype=float32) tf.Tensor(0.5263764, shape=(), dtype=float32) tf.Tensor(1.0095377, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5601984, shape=(), dtype=float32) tf.Tensor(0.49510404, shape=(), dtype=float32) tf.Tensor(0.96461654, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5689449, shape=(), dtype=float32) tf.Tensor(0.60710454, shape=(), dtype=float32) tf.Tensor(0.96892, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3686883, shape=(), dtype=float32) tf.Tensor(0.43626675, shape=(), dtype=float32) tf.Tensor(0.8923893, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3449382, shape=(), dtype=float32) tf.Tensor(0.50382966, shape=(), dtype=float32) tf.Tensor(0.84695476, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5893439, shape=(), dtype=float32) tf.Tensor(0.5676566, shape=(), dtype=float32) tf.Tensor(0.985474, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6352509, shape=(), dtype=float32) tf.Tensor(0.555536, shape=(), dtype=float32) tf.Tensor(1.0256107, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5066504, shape=(), dtype=float32) tf.Tensor(0.60845715, shape=(), dtype=float32) tf.Tensor(0.9894135, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7617064, shape=(), dtype=float32) tf.Tensor(0.5225641, shape=(), dtype=float32) tf.Tensor(1.0204804, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5296438, shape=(), dtype=float32) tf.Tensor(0.4790517, shape=(), dtype=float32) tf.Tensor(0.87974894, shape=(), dtype=float32)
# loss_r:  tf.Tensor(4.515902, shape=(), dtype=float32) tf.Tensor(0.4057965, shape=(), dtype=float32) tf.Tensor(1.127321, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4741375, shape=(), dtype=float32) tf.Tensor(0.59937257, shape=(), dtype=float32) tf.Tensor(0.90910876, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0691785, shape=(), dtype=float32) tf.Tensor(0.5430454, shape=(), dtype=float32) tf.Tensor(0.73387885, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6709583, shape=(), dtype=float32) tf.Tensor(0.41557634, shape=(), dtype=float32) tf.Tensor(0.91982275, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3472769, shape=(), dtype=float32) tf.Tensor(0.4649211, shape=(), dtype=float32) tf.Tensor(0.8661305, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2917787, shape=(), dtype=float32) tf.Tensor(0.45583892, shape=(), dtype=float32) tf.Tensor(0.85031533, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2310132, shape=(), dtype=float32) tf.Tensor(0.5977566, shape=(), dtype=float32) tf.Tensor(0.83690494, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3808411, shape=(), dtype=float32) tf.Tensor(0.39739707, shape=(), dtype=float32) tf.Tensor(0.81130564, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6133974, shape=(), dtype=float32) tf.Tensor(0.51012415, shape=(), dtype=float32) tf.Tensor(0.8415518, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2411586, shape=(), dtype=float32) tf.Tensor(0.46039182, shape=(), dtype=float32) tf.Tensor(0.82910395, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1703026, shape=(), dtype=float32) tf.Tensor(0.3782617, shape=(), dtype=float32) tf.Tensor(0.78553367, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.346016, shape=(), dtype=float32) tf.Tensor(0.37673968, shape=(), dtype=float32) tf.Tensor(0.7993593, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4252673, shape=(), dtype=float32) tf.Tensor(0.39371943, shape=(), dtype=float32) tf.Tensor(0.90472394, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3928664, shape=(), dtype=float32) tf.Tensor(0.47891766, shape=(), dtype=float32) tf.Tensor(0.8112063, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6330866, shape=(), dtype=float32) tf.Tensor(0.4148012, shape=(), dtype=float32) tf.Tensor(0.7749229, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2482339, shape=(), dtype=float32) tf.Tensor(0.37016785, shape=(), dtype=float32) tf.Tensor(0.77663267, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9354023, shape=(), dtype=float32) tf.Tensor(0.4284073, shape=(), dtype=float32) tf.Tensor(0.8540869, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6789882, shape=(), dtype=float32) tf.Tensor(0.37132367, shape=(), dtype=float32) tf.Tensor(0.7914843, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6136247, shape=(), dtype=float32) tf.Tensor(0.6558817, shape=(), dtype=float32) tf.Tensor(0.89068675, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3260359, shape=(), dtype=float32) tf.Tensor(0.50107956, shape=(), dtype=float32) tf.Tensor(0.779048, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5630484, shape=(), dtype=float32) tf.Tensor(0.4715594, shape=(), dtype=float32) tf.Tensor(0.78915334, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4978663, shape=(), dtype=float32) tf.Tensor(0.413084, shape=(), dtype=float32) tf.Tensor(0.8162109, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4685763, shape=(), dtype=float32) tf.Tensor(0.35748082, shape=(), dtype=float32) tf.Tensor(0.8171903, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9145923, shape=(), dtype=float32) tf.Tensor(0.44324127, shape=(), dtype=float32) tf.Tensor(0.6289133, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4629279, shape=(), dtype=float32) tf.Tensor(0.3698745, shape=(), dtype=float32) tf.Tensor(0.82466245, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3905934, shape=(), dtype=float32) tf.Tensor(0.30453023, shape=(), dtype=float32) tf.Tensor(0.72757673, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7484784, shape=(), dtype=float32) tf.Tensor(0.33818683, shape=(), dtype=float32) tf.Tensor(0.8593994, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.0459714, shape=(), dtype=float32) tf.Tensor(0.37876478, shape=(), dtype=float32) tf.Tensor(0.8266386, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2751422, shape=(), dtype=float32) tf.Tensor(0.2736197, shape=(), dtype=float32) tf.Tensor(0.7280595, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2496268, shape=(), dtype=float32) tf.Tensor(0.37015322, shape=(), dtype=float32) tf.Tensor(0.66062784, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.91414285, shape=(), dtype=float32) tf.Tensor(0.38662156, shape=(), dtype=float32) tf.Tensor(0.6658516, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7982795, shape=(), dtype=float32) tf.Tensor(0.41437477, shape=(), dtype=float32) tf.Tensor(0.7920572, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.8731236, shape=(), dtype=float32) tf.Tensor(0.5054306, shape=(), dtype=float32) tf.Tensor(0.8786943, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.9018645, shape=(), dtype=float32) tf.Tensor(0.32789046, shape=(), dtype=float32) tf.Tensor(0.71655804, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1784253, shape=(), dtype=float32) tf.Tensor(0.38532668, shape=(), dtype=float32) tf.Tensor(0.75906867, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0658712, shape=(), dtype=float32) tf.Tensor(0.25341478, shape=(), dtype=float32) tf.Tensor(0.6333605, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.97363764, shape=(), dtype=float32) tf.Tensor(0.3956891, shape=(), dtype=float32) tf.Tensor(0.6647004, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7088314, shape=(), dtype=float32) tf.Tensor(0.43384948, shape=(), dtype=float32) tf.Tensor(0.7808529, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4815574, shape=(), dtype=float32) tf.Tensor(0.38865453, shape=(), dtype=float32) tf.Tensor(0.76234126, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.97320724, shape=(), dtype=float32) tf.Tensor(0.33677012, shape=(), dtype=float32) tf.Tensor(0.6201197, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.93043846, shape=(), dtype=float32) tf.Tensor(0.34811926, shape=(), dtype=float32) tf.Tensor(0.6412245, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0704845, shape=(), dtype=float32) tf.Tensor(0.4125298, shape=(), dtype=float32) tf.Tensor(0.62927705, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.7848241, shape=(), dtype=float32) tf.Tensor(0.42210504, shape=(), dtype=float32) tf.Tensor(0.8503182, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0140207, shape=(), dtype=float32) tf.Tensor(0.2708484, shape=(), dtype=float32) tf.Tensor(0.62978417, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6872636, shape=(), dtype=float32) tf.Tensor(0.304991, shape=(), dtype=float32) tf.Tensor(0.7063029, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1301231, shape=(), dtype=float32) tf.Tensor(0.32816446, shape=(), dtype=float32) tf.Tensor(0.6948309, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4436351, shape=(), dtype=float32) tf.Tensor(0.38425657, shape=(), dtype=float32) tf.Tensor(0.63434327, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1795795, shape=(), dtype=float32) tf.Tensor(0.37828654, shape=(), dtype=float32) tf.Tensor(0.71212006, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3057642, shape=(), dtype=float32) tf.Tensor(0.32744855, shape=(), dtype=float32) tf.Tensor(0.65680385, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9125273, shape=(), dtype=float32) tf.Tensor(0.38077202, shape=(), dtype=float32) tf.Tensor(0.65816927, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.927626, shape=(), dtype=float32) tf.Tensor(0.39860907, shape=(), dtype=float32) tf.Tensor(0.6551382, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.323741, shape=(), dtype=float32) tf.Tensor(0.36487627, shape=(), dtype=float32) tf.Tensor(0.6890004, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.89560795, shape=(), dtype=float32) tf.Tensor(0.26982343, shape=(), dtype=float32) tf.Tensor(0.5575592, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.8605113, shape=(), dtype=float32) tf.Tensor(0.50755346, shape=(), dtype=float32) tf.Tensor(0.76673543, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8254495, shape=(), dtype=float32) tf.Tensor(0.34227133, shape=(), dtype=float32) tf.Tensor(0.6180284, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5470638, shape=(), dtype=float32) tf.Tensor(0.40133667, shape=(), dtype=float32) tf.Tensor(0.67955697, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0499796, shape=(), dtype=float32) tf.Tensor(0.29922017, shape=(), dtype=float32) tf.Tensor(0.6253442, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.987748, shape=(), dtype=float32) tf.Tensor(0.28923455, shape=(), dtype=float32) tf.Tensor(0.5373905, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.61119, shape=(), dtype=float32) tf.Tensor(0.23953904, shape=(), dtype=float32) tf.Tensor(0.68008924, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2946444, shape=(), dtype=float32) tf.Tensor(0.2914291, shape=(), dtype=float32) tf.Tensor(0.7181577, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.75067836, shape=(), dtype=float32) tf.Tensor(0.38175488, shape=(), dtype=float32) tf.Tensor(0.5406103, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1454424, shape=(), dtype=float32) tf.Tensor(0.27912778, shape=(), dtype=float32) tf.Tensor(0.7421454, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.98433286, shape=(), dtype=float32) tf.Tensor(0.40479344, shape=(), dtype=float32) tf.Tensor(0.69529593, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2071606, shape=(), dtype=float32) tf.Tensor(0.3751833, shape=(), dtype=float32) tf.Tensor(0.64564824, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0080943, shape=(), dtype=float32) tf.Tensor(0.30888176, shape=(), dtype=float32) tf.Tensor(0.54585385, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4522998, shape=(), dtype=float32) tf.Tensor(0.28529885, shape=(), dtype=float32) tf.Tensor(0.6906273, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3264375, shape=(), dtype=float32) tf.Tensor(0.26999515, shape=(), dtype=float32) tf.Tensor(0.5702529, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.92153835, shape=(), dtype=float32) tf.Tensor(0.23906723, shape=(), dtype=float32) tf.Tensor(0.5359326, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0966063, shape=(), dtype=float32) tf.Tensor(0.32160693, shape=(), dtype=float32) tf.Tensor(0.6238291, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7896022, shape=(), dtype=float32) tf.Tensor(0.37878227, shape=(), dtype=float32) tf.Tensor(0.6116242, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4356545, shape=(), dtype=float32) tf.Tensor(0.3031941, shape=(), dtype=float32) tf.Tensor(0.6975279, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.98182845, shape=(), dtype=float32) tf.Tensor(0.3071803, shape=(), dtype=float32) tf.Tensor(0.57451594, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1847032, shape=(), dtype=float32) tf.Tensor(0.34256998, shape=(), dtype=float32) tf.Tensor(0.6780037, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.92771935, shape=(), dtype=float32) tf.Tensor(0.23975046, shape=(), dtype=float32) tf.Tensor(0.5907322, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5609162, shape=(), dtype=float32) tf.Tensor(0.3542043, shape=(), dtype=float32) tf.Tensor(0.6822737, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1780554, shape=(), dtype=float32) tf.Tensor(0.24205066, shape=(), dtype=float32) tf.Tensor(0.6243007, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0331002, shape=(), dtype=float32) tf.Tensor(0.32741103, shape=(), dtype=float32) tf.Tensor(0.61787766, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5207254, shape=(), dtype=float32) tf.Tensor(0.3380031, shape=(), dtype=float32) tf.Tensor(0.68142843, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5432088, shape=(), dtype=float32) tf.Tensor(0.2850667, shape=(), dtype=float32) tf.Tensor(0.63651085, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0759034, shape=(), dtype=float32) tf.Tensor(0.42387462, shape=(), dtype=float32) tf.Tensor(0.6258131, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1345938, shape=(), dtype=float32) tf.Tensor(0.2825245, shape=(), dtype=float32) tf.Tensor(0.6370899, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2338032, shape=(), dtype=float32) tf.Tensor(0.2926921, shape=(), dtype=float32) tf.Tensor(0.583106, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2002403, shape=(), dtype=float32) tf.Tensor(0.2243438, shape=(), dtype=float32) tf.Tensor(0.71579564, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1920018, shape=(), dtype=float32) tf.Tensor(0.23667914, shape=(), dtype=float32) tf.Tensor(0.64236766, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1246719, shape=(), dtype=float32) tf.Tensor(0.20614292, shape=(), dtype=float32) tf.Tensor(0.66487956, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0142897, shape=(), dtype=float32) tf.Tensor(0.356598, shape=(), dtype=float32) tf.Tensor(0.59850174, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9017177, shape=(), dtype=float32) tf.Tensor(0.2119359, shape=(), dtype=float32) tf.Tensor(0.5331153, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9087844, shape=(), dtype=float32) tf.Tensor(0.2593723, shape=(), dtype=float32) tf.Tensor(0.63168824, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0854714, shape=(), dtype=float32) tf.Tensor(0.26890764, shape=(), dtype=float32) tf.Tensor(0.6238402, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8803256, shape=(), dtype=float32) tf.Tensor(0.2770444, shape=(), dtype=float32) tf.Tensor(0.5934315, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9316013, shape=(), dtype=float32) tf.Tensor(0.24201785, shape=(), dtype=float32) tf.Tensor(0.6000369, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3489636, shape=(), dtype=float32) tf.Tensor(0.37647808, shape=(), dtype=float32) tf.Tensor(0.73565406, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.277324, shape=(), dtype=float32) tf.Tensor(0.22880705, shape=(), dtype=float32) tf.Tensor(0.6143149, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5555896, shape=(), dtype=float32) tf.Tensor(0.25728402, shape=(), dtype=float32) tf.Tensor(0.59681934, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1726463, shape=(), dtype=float32) tf.Tensor(0.23880859, shape=(), dtype=float32) tf.Tensor(0.570765, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.250857, shape=(), dtype=float32) tf.Tensor(0.34577373, shape=(), dtype=float32) tf.Tensor(0.62316567, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2256511, shape=(), dtype=float32) tf.Tensor(0.23295417, shape=(), dtype=float32) tf.Tensor(0.6268093, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.123696, shape=(), dtype=float32) tf.Tensor(0.27005205, shape=(), dtype=float32) tf.Tensor(0.5157129, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.83203447, shape=(), dtype=float32) tf.Tensor(0.25494984, shape=(), dtype=float32) tf.Tensor(0.54244554, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0997485, shape=(), dtype=float32) tf.Tensor(0.25505733, shape=(), dtype=float32) tf.Tensor(0.560048, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.83575684, shape=(), dtype=float32) tf.Tensor(0.32250372, shape=(), dtype=float32) tf.Tensor(0.5798239, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.97220695, shape=(), dtype=float32) tf.Tensor(0.2623754, shape=(), dtype=float32) tf.Tensor(0.56384426, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7563779, shape=(), dtype=float32) tf.Tensor(0.43149346, shape=(), dtype=float32) tf.Tensor(0.5513692, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1725427, shape=(), dtype=float32) tf.Tensor(0.39721853, shape=(), dtype=float32) tf.Tensor(0.61862135, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3174443, shape=(), dtype=float32) tf.Tensor(0.3261564, shape=(), dtype=float32) tf.Tensor(0.6153753, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1768408, shape=(), dtype=float32) tf.Tensor(0.31018147, shape=(), dtype=float32) tf.Tensor(0.5607231, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9022256, shape=(), dtype=float32) tf.Tensor(0.21638648, shape=(), dtype=float32) tf.Tensor(0.529911, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0096586, shape=(), dtype=float32) tf.Tensor(0.38954526, shape=(), dtype=float32) tf.Tensor(0.6358851, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2560183, shape=(), dtype=float32) tf.Tensor(0.2350936, shape=(), dtype=float32) tf.Tensor(0.5828958, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2051716, shape=(), dtype=float32) tf.Tensor(0.38382462, shape=(), dtype=float32) tf.Tensor(0.6602662, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1800115, shape=(), dtype=float32) tf.Tensor(0.27814418, shape=(), dtype=float32) tf.Tensor(0.64629436, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1136789, shape=(), dtype=float32) tf.Tensor(0.17811492, shape=(), dtype=float32) tf.Tensor(0.57097596, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0404996, shape=(), dtype=float32) tf.Tensor(0.23829325, shape=(), dtype=float32) tf.Tensor(0.5274827, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0517913, shape=(), dtype=float32) tf.Tensor(0.29180363, shape=(), dtype=float32) tf.Tensor(0.5489321, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0173563, shape=(), dtype=float32) tf.Tensor(0.31962717, shape=(), dtype=float32) tf.Tensor(0.5898436, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8646644, shape=(), dtype=float32) tf.Tensor(0.36879438, shape=(), dtype=float32) tf.Tensor(0.58134246, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4588125, shape=(), dtype=float32) tf.Tensor(0.24500784, shape=(), dtype=float32) tf.Tensor(0.696903, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9858212, shape=(), dtype=float32) tf.Tensor(0.2770178, shape=(), dtype=float32) tf.Tensor(0.5323642, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0972104, shape=(), dtype=float32) tf.Tensor(0.31037003, shape=(), dtype=float32) tf.Tensor(0.5648577, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2041624, shape=(), dtype=float32) tf.Tensor(0.15678374, shape=(), dtype=float32) tf.Tensor(0.5995419, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0113611, shape=(), dtype=float32) tf.Tensor(0.33981606, shape=(), dtype=float32) tf.Tensor(0.5781627, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3134191, shape=(), dtype=float32) tf.Tensor(0.2899027, shape=(), dtype=float32) tf.Tensor(0.5860919, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1544327, shape=(), dtype=float32) tf.Tensor(0.37122044, shape=(), dtype=float32) tf.Tensor(0.61147606, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5555419, shape=(), dtype=float32) tf.Tensor(0.2659902, shape=(), dtype=float32) tf.Tensor(0.6724471, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8155303, shape=(), dtype=float32) tf.Tensor(0.21430276, shape=(), dtype=float32) tf.Tensor(0.48696542, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.073356, shape=(), dtype=float32) tf.Tensor(0.34509167, shape=(), dtype=float32) tf.Tensor(0.5683816, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.094459, shape=(), dtype=float32) tf.Tensor(0.240164, shape=(), dtype=float32) tf.Tensor(0.5423568, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3806897, shape=(), dtype=float32) tf.Tensor(0.29900008, shape=(), dtype=float32) tf.Tensor(0.48998988, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3983127, shape=(), dtype=float32) tf.Tensor(0.31833583, shape=(), dtype=float32) tf.Tensor(0.6751133, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7297597, shape=(), dtype=float32) tf.Tensor(0.3455128, shape=(), dtype=float32) tf.Tensor(0.50061953, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9260954, shape=(), dtype=float32) tf.Tensor(0.3518017, shape=(), dtype=float32) tf.Tensor(0.5591678, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1053379, shape=(), dtype=float32) tf.Tensor(0.18846151, shape=(), dtype=float32) tf.Tensor(0.61688817, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.6297668, shape=(), dtype=float32) tf.Tensor(0.19795498, shape=(), dtype=float32) tf.Tensor(0.5630375, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.038947, shape=(), dtype=float32) tf.Tensor(0.30529192, shape=(), dtype=float32) tf.Tensor(0.5510433, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8296052, shape=(), dtype=float32) tf.Tensor(0.30056855, shape=(), dtype=float32) tf.Tensor(0.5368954, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7051664, shape=(), dtype=float32) tf.Tensor(0.3413438, shape=(), dtype=float32) tf.Tensor(0.5001493, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6530749, shape=(), dtype=float32) tf.Tensor(0.25967988, shape=(), dtype=float32) tf.Tensor(0.4678141, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.80248624, shape=(), dtype=float32) tf.Tensor(0.42073956, shape=(), dtype=float32) tf.Tensor(0.5828173, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.88443, shape=(), dtype=float32) tf.Tensor(0.33856228, shape=(), dtype=float32) tf.Tensor(0.56655025, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.83409184, shape=(), dtype=float32) tf.Tensor(0.282743, shape=(), dtype=float32) tf.Tensor(0.5188733, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.86420614, shape=(), dtype=float32) tf.Tensor(0.22902417, shape=(), dtype=float32) tf.Tensor(0.47334945, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.2052538, shape=(), dtype=float32) tf.Tensor(0.30285528, shape=(), dtype=float32) tf.Tensor(0.65147495, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7580832, shape=(), dtype=float32) tf.Tensor(0.28451195, shape=(), dtype=float32) tf.Tensor(0.53751636, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1600704, shape=(), dtype=float32) tf.Tensor(0.36628845, shape=(), dtype=float32) tf.Tensor(0.57048786, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.903834, shape=(), dtype=float32) tf.Tensor(0.32029018, shape=(), dtype=float32) tf.Tensor(0.55049837, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.7815279, shape=(), dtype=float32) tf.Tensor(0.31018975, shape=(), dtype=float32) tf.Tensor(0.62354517, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6563168, shape=(), dtype=float32) tf.Tensor(0.24788392, shape=(), dtype=float32) tf.Tensor(0.47076952, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.81421393, shape=(), dtype=float32) tf.Tensor(0.17189851, shape=(), dtype=float32) tf.Tensor(0.5229822, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1595396, shape=(), dtype=float32) tf.Tensor(0.33714896, shape=(), dtype=float32) tf.Tensor(0.64864045, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8028034, shape=(), dtype=float32) tf.Tensor(0.30696025, shape=(), dtype=float32) tf.Tensor(0.5765228, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.132268, shape=(), dtype=float32) tf.Tensor(0.21774922, shape=(), dtype=float32) tf.Tensor(0.54655546, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0634412, shape=(), dtype=float32) tf.Tensor(0.20049691, shape=(), dtype=float32) tf.Tensor(0.49037644, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2508764, shape=(), dtype=float32) tf.Tensor(0.1993516, shape=(), dtype=float32) tf.Tensor(0.5661981, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2268949, shape=(), dtype=float32) tf.Tensor(0.2143855, shape=(), dtype=float32) tf.Tensor(0.59209037, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9023775, shape=(), dtype=float32) tf.Tensor(0.41367757, shape=(), dtype=float32) tf.Tensor(0.5450789, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.5441338, shape=(), dtype=float32) tf.Tensor(0.33245155, shape=(), dtype=float32) tf.Tensor(0.64675504, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2419052, shape=(), dtype=float32) tf.Tensor(0.34880295, shape=(), dtype=float32) tf.Tensor(0.5594993, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1015642, shape=(), dtype=float32) tf.Tensor(0.3138969, shape=(), dtype=float32) tf.Tensor(0.59967947, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9973568, shape=(), dtype=float32) tf.Tensor(0.21966763, shape=(), dtype=float32) tf.Tensor(0.46113113, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.234152, shape=(), dtype=float32) tf.Tensor(0.20377077, shape=(), dtype=float32) tf.Tensor(0.5754872, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2795227, shape=(), dtype=float32) tf.Tensor(0.30726472, shape=(), dtype=float32) tf.Tensor(0.57031703, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1238333, shape=(), dtype=float32) tf.Tensor(0.33732417, shape=(), dtype=float32) tf.Tensor(0.5581914, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3385748, shape=(), dtype=float32) tf.Tensor(0.31068426, shape=(), dtype=float32) tf.Tensor(0.76624393, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.869392, shape=(), dtype=float32) tf.Tensor(0.35039917, shape=(), dtype=float32) tf.Tensor(0.5675584, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.85749614, shape=(), dtype=float32) tf.Tensor(0.1956343, shape=(), dtype=float32) tf.Tensor(0.50666076, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2700921, shape=(), dtype=float32) tf.Tensor(0.32187122, shape=(), dtype=float32) tf.Tensor(0.5803663, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3789501, shape=(), dtype=float32) tf.Tensor(0.27930388, shape=(), dtype=float32) tf.Tensor(0.5150496, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8682316, shape=(), dtype=float32) tf.Tensor(0.28670448, shape=(), dtype=float32) tf.Tensor(0.5171647, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.85678476, shape=(), dtype=float32) tf.Tensor(0.32429442, shape=(), dtype=float32) tf.Tensor(0.4795975, shape=(), dtype=float32)
# loss_r:  tf.Tensor(2.1609786, shape=(), dtype=float32) tf.Tensor(0.2092477, shape=(), dtype=float32) tf.Tensor(0.6265947, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.89547557, shape=(), dtype=float32) tf.Tensor(0.30809343, shape=(), dtype=float32) tf.Tensor(0.55639094, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.78694206, shape=(), dtype=float32) tf.Tensor(0.18526356, shape=(), dtype=float32) tf.Tensor(0.47523212, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.4641379, shape=(), dtype=float32) tf.Tensor(0.37720636, shape=(), dtype=float32) tf.Tensor(0.6330025, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7018206, shape=(), dtype=float32) tf.Tensor(0.2721449, shape=(), dtype=float32) tf.Tensor(0.48856628, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0111464, shape=(), dtype=float32) tf.Tensor(0.23269838, shape=(), dtype=float32) tf.Tensor(0.537385, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8928632, shape=(), dtype=float32) tf.Tensor(0.24180749, shape=(), dtype=float32) tf.Tensor(0.54885864, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.88421434, shape=(), dtype=float32) tf.Tensor(0.2653894, shape=(), dtype=float32) tf.Tensor(0.5006343, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7748466, shape=(), dtype=float32) tf.Tensor(0.1300662, shape=(), dtype=float32) tf.Tensor(0.45240748, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.73465943, shape=(), dtype=float32) tf.Tensor(0.35599336, shape=(), dtype=float32) tf.Tensor(0.4900286, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6594961, shape=(), dtype=float32) tf.Tensor(0.1775027, shape=(), dtype=float32) tf.Tensor(0.40497798, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6902649, shape=(), dtype=float32) tf.Tensor(0.18508323, shape=(), dtype=float32) tf.Tensor(0.45643473, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.063281, shape=(), dtype=float32) tf.Tensor(0.28634095, shape=(), dtype=float32) tf.Tensor(0.4760532, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7854315, shape=(), dtype=float32) tf.Tensor(0.16486849, shape=(), dtype=float32) tf.Tensor(0.47814676, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2254593, shape=(), dtype=float32) tf.Tensor(0.31086758, shape=(), dtype=float32) tf.Tensor(0.5461197, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3285292, shape=(), dtype=float32) tf.Tensor(0.21876168, shape=(), dtype=float32) tf.Tensor(0.58642876, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.908173, shape=(), dtype=float32) tf.Tensor(0.22822946, shape=(), dtype=float32) tf.Tensor(0.47994417, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9022945, shape=(), dtype=float32) tf.Tensor(0.26383117, shape=(), dtype=float32) tf.Tensor(0.49777037, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0521042, shape=(), dtype=float32) tf.Tensor(0.18881576, shape=(), dtype=float32) tf.Tensor(0.46744546, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.91424924, shape=(), dtype=float32) tf.Tensor(0.23243624, shape=(), dtype=float32) tf.Tensor(0.4445044, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7783557, shape=(), dtype=float32) tf.Tensor(0.25570795, shape=(), dtype=float32) tf.Tensor(0.49370068, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.87995684, shape=(), dtype=float32) tf.Tensor(0.1597209, shape=(), dtype=float32) tf.Tensor(0.49799353, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2403126, shape=(), dtype=float32) tf.Tensor(0.2147967, shape=(), dtype=float32) tf.Tensor(0.5373064, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8022942, shape=(), dtype=float32) tf.Tensor(0.23797598, shape=(), dtype=float32) tf.Tensor(0.45812944, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7931799, shape=(), dtype=float32) tf.Tensor(0.27587467, shape=(), dtype=float32) tf.Tensor(0.50328016, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2029477, shape=(), dtype=float32) tf.Tensor(0.23784849, shape=(), dtype=float32) tf.Tensor(0.48926193, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.59938735, shape=(), dtype=float32) tf.Tensor(0.21999101, shape=(), dtype=float32) tf.Tensor(0.40013614, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.86601835, shape=(), dtype=float32) tf.Tensor(0.24984214, shape=(), dtype=float32) tf.Tensor(0.41535488, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.89860535, shape=(), dtype=float32) tf.Tensor(0.25838748, shape=(), dtype=float32) tf.Tensor(0.5181993, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0315783, shape=(), dtype=float32) tf.Tensor(0.27869627, shape=(), dtype=float32) tf.Tensor(0.5000236, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.88968337, shape=(), dtype=float32) tf.Tensor(0.2069266, shape=(), dtype=float32) tf.Tensor(0.4640514, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8802654, shape=(), dtype=float32) tf.Tensor(0.2215315, shape=(), dtype=float32) tf.Tensor(0.49159795, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7459158, shape=(), dtype=float32) tf.Tensor(0.2978994, shape=(), dtype=float32) tf.Tensor(0.5225832, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.536156, shape=(), dtype=float32) tf.Tensor(0.29456764, shape=(), dtype=float32) tf.Tensor(0.40496826, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.7264751, shape=(), dtype=float32) tf.Tensor(0.20375246, shape=(), dtype=float32) tf.Tensor(0.45102096, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8302266, shape=(), dtype=float32) tf.Tensor(0.2941751, shape=(), dtype=float32) tf.Tensor(0.48067302, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.2510856, shape=(), dtype=float32) tf.Tensor(0.21883479, shape=(), dtype=float32) tf.Tensor(0.5009145, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8312712, shape=(), dtype=float32) tf.Tensor(0.22800857, shape=(), dtype=float32) tf.Tensor(0.49219024, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.75076413, shape=(), dtype=float32) tf.Tensor(0.3032872, shape=(), dtype=float32) tf.Tensor(0.46741733, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9146401, shape=(), dtype=float32) tf.Tensor(0.16703083, shape=(), dtype=float32) tf.Tensor(0.46542913, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.3504685, shape=(), dtype=float32) tf.Tensor(0.3047815, shape=(), dtype=float32) tf.Tensor(0.55191314, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.90126806, shape=(), dtype=float32) tf.Tensor(0.286916, shape=(), dtype=float32) tf.Tensor(0.4585822, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6441342, shape=(), dtype=float32) tf.Tensor(0.1480327, shape=(), dtype=float32) tf.Tensor(0.38317695, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0617112, shape=(), dtype=float32) tf.Tensor(0.22526968, shape=(), dtype=float32) tf.Tensor(0.4743346, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.297736, shape=(), dtype=float32) tf.Tensor(0.16821612, shape=(), dtype=float32) tf.Tensor(0.49443743, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9011215, shape=(), dtype=float32) tf.Tensor(0.20777167, shape=(), dtype=float32) tf.Tensor(0.47230664, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6413777, shape=(), dtype=float32) tf.Tensor(0.2977721, shape=(), dtype=float32) tf.Tensor(0.4360075, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0350885, shape=(), dtype=float32) tf.Tensor(0.2123716, shape=(), dtype=float32) tf.Tensor(0.47047374, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6291565, shape=(), dtype=float32) tf.Tensor(0.22066744, shape=(), dtype=float32) tf.Tensor(0.42503026, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.635298, shape=(), dtype=float32) tf.Tensor(0.20015652, shape=(), dtype=float32) tf.Tensor(0.45118764, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.88467574, shape=(), dtype=float32) tf.Tensor(0.31449363, shape=(), dtype=float32) tf.Tensor(0.47632882, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.5935971, shape=(), dtype=float32) tf.Tensor(0.28451473, shape=(), dtype=float32) tf.Tensor(0.43862984, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.71184224, shape=(), dtype=float32) tf.Tensor(0.1750956, shape=(), dtype=float32) tf.Tensor(0.4232859, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0605823, shape=(), dtype=float32) tf.Tensor(0.2046199, shape=(), dtype=float32) tf.Tensor(0.39247268, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0477278, shape=(), dtype=float32) tf.Tensor(0.23621716, shape=(), dtype=float32) tf.Tensor(0.48580498, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.70208746, shape=(), dtype=float32) tf.Tensor(0.2304291, shape=(), dtype=float32) tf.Tensor(0.43099654, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.1463131, shape=(), dtype=float32) tf.Tensor(0.21026978, shape=(), dtype=float32) tf.Tensor(0.42473406, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.90003353, shape=(), dtype=float32) tf.Tensor(0.25312474, shape=(), dtype=float32) tf.Tensor(0.47497565, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.74815434, shape=(), dtype=float32) tf.Tensor(0.22789925, shape=(), dtype=float32) tf.Tensor(0.47147512, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0695235, shape=(), dtype=float32) tf.Tensor(0.16931246, shape=(), dtype=float32) tf.Tensor(0.4747517, shape=(), dtype=float32)
# loss_r:  tf.Tensor(1.0731804, shape=(), dtype=float32) tf.Tensor(0.19839607, shape=(), dtype=float32) tf.Tensor(0.48651192, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.6997738, shape=(), dtype=float32) tf.Tensor(0.24061558, shape=(), dtype=float32) tf.Tensor(0.40038103, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.83602506, shape=(), dtype=float32) tf.Tensor(0.1548936, shape=(), dtype=float32) tf.Tensor(0.44563195, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8017961, shape=(), dtype=float32) tf.Tensor(0.2823214, shape=(), dtype=float32) tf.Tensor(0.47497877, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.60270137, shape=(), dtype=float32) tf.Tensor(0.26110134, shape=(), dtype=float32) tf.Tensor(0.3961982, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.62316847, shape=(), dtype=float32) tf.Tensor(0.21270512, shape=(), dtype=float32) tf.Tensor(0.4137482, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.9379543, shape=(), dtype=float32) tf.Tensor(0.23208892, shape=(), dtype=float32) tf.Tensor(0.4392827, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.85283005, shape=(), dtype=float32) tf.Tensor(0.2489784, shape=(), dtype=float32) tf.Tensor(0.45407575, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.8305709, shape=(), dtype=float32) tf.Tensor(0.19706188, shape=(), dtype=float32) tf.Tensor(0.39551505, shape=(), dtype=float32)
# loss_r:  tf.Tensor(0.52960175, shape=(), dtype=float32) tf.Tensor(0.1976893, shape=(), dtype=float32) tf.Tensor(0.37353006, shape=(), dtype=float32)
# Time for epoch 1 is 65.94497394561768 sec

# %%
#fig = plt.figure(figsize=(18,6)) # commenting this out makes the images smaller
plt.subplot(1, 3, 1)
plt.imshow(valid_data[1, :, :, 0], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.imshow(valid_data[2, :, :, 1], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.imshow(valid_data[3, :, :, 0], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)
